# %%
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
#import pandas_profiling as pp

# %%
df = pd.read_csv('/home/abrol/ARYAN_MT22019/CoughVid/public_dataset/metadata_compiled.csv')

# %%
df.head()
# Out:
#                                    uuid                          datetime  \
# 0  00039425-7f3a-42aa-ac13-834aaa2b6b92  2020-04-13T21:30:59.801831+00:00
# 1  0009eb28-d8be-4dc1-92bb-907e53bc5c7a  2020-04-12T04:02:18.159383+00:00
# 2  0012c608-33d0-4ef7-bde3-75a0b1a0024e  2020-04-15T01:03:59.029326+00:00
# 3  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f  2020-04-13T22:23:06.997578+00:00
# 4  001c85a8-cc4d-4921-9297-848be52d4715  2020-04-17T15:24:35.822355+00:00
#
#    cough_detected  latitude  longitude   age gender respiratory_condition  \
# 0          0.9609      31.3       34.8  15.0   male                 False
# 1          0.9301      40.0      -75.1  34.0   male                  True
# 2          0.0482     -16.5      -71.5   NaN    NaN                   NaN
# 3          0.9968       NaN        NaN  21.0   male                 False
# 4          0.0735      40.6       -3.6   NaN    NaN                   NaN
#
# ...

# %%
df['datetime']
# Out:
# 0        2020-04-13T21:30:59.801831+00:00
# 1        2020-04-12T04:02:18.159383+00:00
# 2        2020-04-15T01:03:59.029326+00:00
# 3        2020-04-13T22:23:06.997578+00:00
# 4        2020-04-17T15:24:35.822355+00:00
#                        ...
# 20067    2020-04-13T17:51:36.956822+00:00
# 20068    2020-06-28T21:28:21.530881+00:00
# 20069    2020-04-10T05:10:36.787070+00:00
# 20070    2020-04-13T18:58:26.954663+00:00
# 20071    2020-04-14T13:02:33.307684+00:00
# Name: datetime, Length: 20072, dtype: object

# %%
import datetime as dt

# %%
dtime = pd.to_datetime(df["datetime"]).dt

# %%
df["date"] = dtime.date

# %%
df.head()
# Out:
#                                    uuid                          datetime  \
# 0  00039425-7f3a-42aa-ac13-834aaa2b6b92  2020-04-13T21:30:59.801831+00:00
# 1  0009eb28-d8be-4dc1-92bb-907e53bc5c7a  2020-04-12T04:02:18.159383+00:00
# 2  0012c608-33d0-4ef7-bde3-75a0b1a0024e  2020-04-15T01:03:59.029326+00:00
# 3  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f  2020-04-13T22:23:06.997578+00:00
# 4  001c85a8-cc4d-4921-9297-848be52d4715  2020-04-17T15:24:35.822355+00:00
#
#    cough_detected  latitude  longitude   age gender respiratory_condition  \
# 0          0.9609      31.3       34.8  15.0   male                 False
# 1          0.9301      40.0      -75.1  34.0   male                  True
# 2          0.0482     -16.5      -71.5   NaN    NaN                   NaN
# 3          0.9968       NaN        NaN  21.0   male                 False
# 4          0.0735      40.6       -3.6   NaN    NaN                   NaN
#
# ...

# %%
df["hour"] = dtime.hour

# %%
df["min"] = dtime.minute

# %%
df["month"] = dtime.month

# %%
df["day_name"] = dtime.day_name()

# %%
df.tail()
# Out:
#                                        uuid                          datetime  \
# 20067  fff13fa2-a725-49ef-812a-39c6cedda33d  2020-04-13T17:51:36.956822+00:00
# 20068  fff3ff61-2387-4139-938b-539db01e6be5  2020-06-28T21:28:21.530881+00:00
# 20069  fff474bf-39a4-4a61-8348-6b992fb5e439  2020-04-10T05:10:36.787070+00:00
# 20070  fffaa9f8-4db0-46c5-90fb-93b7b014b55d  2020-04-13T18:58:26.954663+00:00
# 20071  fffce9f0-a5e8-4bee-b13b-c671aac4a61c  2020-04-14T13:02:33.307684+00:00
#
#        cough_detected  latitude  longitude   age  gender  \
# 20067          0.7154      31.9       34.7  21.0    male
# 20068          0.5257      51.6       -0.2   NaN  female
# 20069          0.1945     -39.0      -68.1   NaN     NaN
# 20070          0.0243      41.0       28.8  50.0    male
# 20071          0.9754      41.0       28.7   NaN     NaN
#
#       respiratory_condition fever_muscle_pain       status  ... congestion_3  \
# ...

# %%
df.drop(['datetime'], inplace=True, axis = 1)

# %%
df.head()
# Out:
#                                    uuid  cough_detected  latitude  longitude  \
# 0  00039425-7f3a-42aa-ac13-834aaa2b6b92          0.9609      31.3       34.8
# 1  0009eb28-d8be-4dc1-92bb-907e53bc5c7a          0.9301      40.0      -75.1
# 2  0012c608-33d0-4ef7-bde3-75a0b1a0024e          0.0482     -16.5      -71.5
# 3  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f          0.9968       NaN        NaN
# 4  001c85a8-cc4d-4921-9297-848be52d4715          0.0735      40.6       -3.6
#
#     age gender respiratory_condition fever_muscle_pain   status quality_1  \
# 0  15.0   male                 False             False  healthy       NaN
# 1  34.0   male                  True             False  healthy       NaN
# 2   NaN    NaN                   NaN               NaN      NaN       NaN
# 3  21.0   male                 False             False  healthy       NaN
# 4   NaN    NaN                   NaN               NaN      NaN       NaN
#
# ...

# %%
df.to_csv("updated_vimal1.csv",index= False)
